# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder

# %%
#Archivo con numeros nulos eliminados
df=pd.read_csv('../../datos/house/house_data.csv')

#print(df.head())

#print('\n-----------------------\n')

print(len(df.columns))
print(df.columns)

'''
tipo_vivienda-'MSSubClass', 'MSZoning'
'LotFrontage',
'LotArea',
tipo_acceso-'Street', 'Alley'
ubicacion-'LotShape', 'LandContour','Utilities', 'LotConfig','LandSlope'
'Neighborhood'
proximity-'Condition1', 'Condition2'
caracteristicas-'BldgType', 'HouseStyle'
condicion-'OverallQual', 'OverallCond'
'YearBuilt', 'YearRemodAdd'
roof-'RoofStyle', 'RoofMatl'
exterior-'Exterior1st', 'Exterior2nd'               -Descarte o decir una u otra si_no
Masonry veneer-'MasVnrType','MasVnrArea'            -Si_no y juntar
Exterior_material-'ExterQual', 'ExterCond'
'Foundation'
basement-'BsmtQual','BsmtCond', 'BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF'
Temperature-'Heating','HeatingQC', 'CentralAir'
'Electrical'
pisos_areas-'1stFlrSF', '2ndFlrSF','GrLivArea'
'LowQualFinSF',      -no me convence evaluarla
bathroom-'BsmtFullBath', 'BsmtHalfBath', 'FullBath','HalfBath'      -total baños
cantidadhabitaciones-'BedroomAbvGr'
kitchen-'KitchenAbvGr', 'KitchenQual'
cantidad_rooms-'TotRmsAbvGrd'
'Functional'                -campo importante
fireplace-'Fireplaces', 'FireplaceQu'
garage-'GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea','GarageQual','GarageCond','PavedDrive'
'WoodDeckSF'
porch-'OpenPorchSF','EnclosedPorch', '3SsnPorch', 'ScreenPorch'
pool-'PoolArea', 'PoolQC'
'Fence'
caracextra-'MiscFeature','MiscVal'
fecha-'MoSold','YrSold'                   -no relevante para precio
'SaleType'                                -no relevante para precio
'SaleCondition'
'''
# Out:
# 82
# Index(['Unnamed: 0', 'Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %% [markdown]
# Clasificar SalePrice por cuartiles

# %%
#columna-SalePrice por cuartil clasificar

df_house=df.dropna(inplace=False,subset='SalePrice')

df_house['ClasPrice']=pd.qcut(df_house['SalePrice'],q=4 ,labels=[1,2,3,4])
print(df.head())
# Out:
#    Unnamed: 0  Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0           0   1          60       RL         65.0     8450   Pave   N_A
# 1           1   2          20       RL         80.0     9600   Pave   N_A
# 2           2   3          60       RL         68.0    11250   Pave   N_A
# 3           3   4          70       RL         60.0     9550   Pave   N_A
# 4           4   5          60       RL         84.0    14260   Pave   N_A
#
#   LotShape LandContour  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0      Reg         Lvl  ...        0    N_A   N_A         N_A       0      2
# 1      Reg         Lvl  ...        0    N_A   N_A         N_A       0      5
# 2      IR1         Lvl  ...        0    N_A   N_A         N_A       0      9
# 3      IR1         Lvl  ...        0    N_A   N_A         N_A       0      2
# 4      IR1         Lvl  ...        0    N_A   N_A         N_A       0     12
#
#   YrSold SaleType  SaleCondition  SalePrice
# ...

# %%
'''Siguiente paso-con ordinalencoder asigno numeros a variables tipo string?1_cleaning.ipynb
    -Se pueden establecer correlaciones y ver qué factores afectan al precio

Combinar categorias relacionadas como Bmst... MasVnr... Garage...
'''
df.dtypes
list(df.select_dtypes(include=['object']).columns)
len(list(df.select_dtypes(include=['object']).columns))
# Out:
# 44

# %%
'YearBuilt', 'YearRemodAdd'

df_cons=
figure=plt.figure(figsize = (8, 6))

# %%
df_numerics = df_house.select_dtypes(include = ['float64', 'int64'])
figure=plt.figure(figsize = (60, 90))

for i, column in enumerate(df_numerics.columns, 1):
        axes = figure.add_subplot(19,2,i)
        sns.kdeplot(x = df_numerics[column], hue = df_house['ClasPrice'], fill = True, ax = axes)
        figure.tight_layout()
plt.show()
# Out:
# C:\Users\shiku\AppData\Local\Temp\ipykernel_31648\3033907128.py:6: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x = df_numerics[column], hue = df_house['ClasPrice'], fill = True, ax = axes)
# C:\Users\shiku\AppData\Local\Temp\ipykernel_31648\3033907128.py:6: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x = df_numerics[column], hue = df_house['ClasPrice'], fill = True, ax = axes)
# C:\Users\shiku\AppData\Local\Temp\ipykernel_31648\3033907128.py:6: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x = df_numerics[column], hue = df_house['ClasPrice'], fill = True, ax = axes)

# %%
corr_df = df.corr(method='pearson')
#df[columns].corr
plt.figure(figsize=(8, 6))
sns.heatmap(corr_df, annot=True)
